# %% [markdown]
# # Domácí úkol č. 3 - 📈 Vizualizace ve strojovém učení od A do Z
#
# ## 📚 Data
# Pro tento úkol si studenti **zvolí vhodná data sami**. ☝️ Zvolená data by měla být veřejně dostupná a měla by simulovat nebo odpovídat nějaké reálné situaci (tzn. syntetická/vygenerovaná data neuvažujeme!). Data si vybírejte tak, abyste na nich byli schopni řešit klasifikační nebo regresní úlohu (tedy supervizované učení, přítomnost výstupní proměnné).
#
# **Pro odvážné:** Pokud se cítíte silní v kramflecích, můžete si zvolit i nesupervizovanou úlohu, např. shlukování.
#
# #### Tipy na data a řešení
# V souboru datasets_tips.md můžete najít tipy na různé veřejné weby s datasety.
#
# Inspiraci pro vypracování úkolu najdete v praktických ukázkách k přednáškám č. 8 (cvičení 4) a 11. Nicméně pouze zkopírovaný kód nebude hodnocen kladně.
#
# ☝️**Pozor!** Zkuste si zvolit trochu nápaditý dataset. Pokud si zvolíte dataset, který je často součástí tutoriálů (např. [Titanic dataset](https://www.tensorflow.org/datasets/catalog/titanic) nebo [Iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)), pro zisk plného počtu bodů budete muset zřejmě vynaložit větší úsilí při jeho kreativní a neotřelé prezentaci.
#
# ## Zadání
# > ☝️ Používejte **markdown buňky**! Zdůvodňujte všechny důležité kroky, popisujte vizualizace a co je z nich možné pozorovat. Za nepřehledný domácí úkol nebudou uděleny body.
#
# Za řádné průběžné komentování a vizuální prezentaci postupu a výsledků lze získat až 5 bodů. Notebook odevzdávejte po spuštění (tzn. včetně output buněk) a zkrontrolujte si, že se komentáře korektně zobrazují ('rendered file' na GitLabu ve vašem prohlížeči).
#
# Úkol můžete vypracovávat jako **jednotlivci** nebo **ve skupině maximálně 3 spolužáků**. Postup pro hodnocení skupiny najdete na stránkách předmětu [zde](https://courses.fit.cvut.cz/BI-VIZ/homeworks/index.html#_podrobnosti-k-hodnocen%C3%AD-třet%C3%ADho-úkolu).
#
# ### Pokyny pro vypracování
#
# 🙏 Pokud je to možné, v každém bodě vaší práce **využijte vizualizace** a svá zjištění komentujte.
#
# **📖 Vaše úloha:**
# 1. Popište klasifikační/regresní úlohu, kterou v rámci domácího úkolu budete řešit.
# 2. Uveďte zdroj, odkud čerpáte data. ⛔️ Pozn.: Pokud pracujete s lokálně uloženým datasetem, odevzdejte jej spolu s vyřešeným Jupyter Notebookem prostřednictvím GitLabu. To aby s daty mohl pracovat i vyučující při opravě.
#
# **✨ Dataset:**
# V této části máte za úkol načíst zvolená data a pomocí vizualizace a popisných statistik se s nimi seznámit. Dále je nutné data vhodným způsobem předzpracovat, abyste je mohli použít pro trénování modelu.
# 1. Načtěte si zvolený dataset a importujte potřebné knihovny. Volba knihoven je na vás.
# 2. Představte jednotlivé příznaky pomocí textových popisů.
# 3. Analyzujte dataset pomocí popisných statistik s využitím vhodných vizualizačních metod. Svá zjištění komentujte.
# 4. Vyšetřete chybějící hodnoty (včetně jejich reprezentace) a odlehlá pozorování. Opět využijte vizualizace, pokud je to možné a svá zjištění komentujte.
# 5. Proveďte všechny další úpravy, které jsou podle vás pro práci s vybraným datasetem nezbytné (např. konverze datových typů, odstranění duplicitních údajů, vytvoření nových příznaků, sjednocení reprezentace chybějících dat nebo jejich odstranění apod.). K úpravě datasetu se můžete v průběhu řešení úlohy vracet.
# 6. Připravte dataset tak, abyste na něm mohli natrénovat a vyhodnotit vybraný model (např. data vhodně rozdělte, pokud je to pro váš model a evaluaci nutné, rozdělení komentujte, nebo můžete využít křížovou validaci apod. -> znáte z BI-ML1).
#
# Z této části lze získat celkem 7 bodů.
#
# **⚙️Model:**
# V této části je vaším úkolem natrénovat model, který se pokusí vyřešit vaši úlohu. Zaměřte se především na vizualizaci jednotlivých kroků a výsledků, včetně komentářů. Kvalita modelu jako takového nebude hodnocena.
# 1. Pro svoji úlohu zvolte vhodný klasifikační/regresní model.
# 2. Zvolte si alespoň dva hyperparametry spolu s minimálně pěti hodnotami (zde může být i více, případně méně v závislosti na zvoleném hyperparametru), jejichž nejlepší kombinaci budete během trénování modelu hledat. Zvolené hyperparametry a jejich hodnoty popište.
# 3. Zvolte a popište ztrátovou funkci, pomocí které provedete vyhodnocení úspěšnosti modelu.
# 4. Daný model na datasetu natrénujte. Pokud to lze, model vizualizujte.
# 5. Vhodně vizualizujte a komentujte vliv jednotlivých kombinací hyperparamentrů na úspěšnost modelu. Uveďte nejlepší kombinaci.
# 6. Pokud to lze (!), vizualizujte rozhodovací hranici modelu pro vámi vybrané příznaky (např. pouze pro 2). Pokud to nelze, zdůvodněte, případně realizujte jinou viualizaci související s prezentací nejlepšího modelu.
# 7. Vhodně vizualizujte úspěšnost výsledného modelu - využijte alespoň dvě vizualizační metody.
#
# **Pro zájemce:** Pokud byste chtěli, můžete pro řešení úlohy použít modelů více a provést jejich srovnání (včetně ladění hyperparametrů a dalších kroků zmíněných výše).
#
# Z této části lze získat celkem 18 bodů.
#
# ### Bodové hodnocení
# Shrnutí bodů, které můžete nejvýše získat:
# - 5 bodů za průběžné komentáře a vizuální prezentaci postupu a výsledků,
# - 7 bodů za předzpracování a prezentaci dat,
# - 18 bodů za trénování a vyhodnocení modelu.
#
# Celkem lze za domácí úkol č. 3 získat maximálně 30 bodů (každý člen týmu nebo jednotlivec).

# %% [markdown]
# ## 1. Dataset description

# %% [markdown]
# This dataset is a **cleaned version** of the original Mushroom Dataset for **binary classification**, sourced from the UCI Library. It has been preprocessed using techniques like **modal imputation**, **one-hot encoding**, **z-score normalization**, and **feature selection**.
#
# The dataset was obtained from [Kaggle - Mushroom Dataset by Prisha Sawhney](https://www.kaggle.com/datasets/prishasawhney/mushroom-dataset).
#
#
# ---
#
# ### Features:
# 1. **Cap Diameter**: Numerical feature representing the diameter of the mushroom cap.
# 2. **Cap Shape**: Shape of the cap.
# 3. **Gill Attachment**: How the gills are attached to the stem.
# 4. **Gill Color**: Color of the gills.
# 5. **Stem Height**: Height of the mushroom stem (numerical).
# 6. **Stem Width**: Width of the mushroom stem (numerical).
# 7. **Stem Color**: Color of the stem.
# 8. **Season**: The season when the mushroom is found.
#
# ---
#
# ### Target Variable:
# - **Target Class**: Binary classification label:
#    - `0` → Edible
#    - `1` → Poisonous
#
# ---
#
# ### Summary:
# The dataset contains **9 columns** and has already undergone data cleaning. This makes it a suitable choice for training classification models without dealing with missing values or extensive preprocessing.

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# ### 1. Dataset Overview

# %% [markdown]
# Importing neccessary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, ParameterGrid
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
import sklearn.metrics as metrics
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import precision_recall_curve, roc_curve, auc, average_precision_score
random_seed = 322

# %% [markdown]
# Reading our dataset.

# %%
mushroom_df = pd.read_csv("mushroom.csv")
mushroom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54035 entries, 0 to 54034
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cap-diameter     54035 non-null  int64
#  1   cap-shape        54035 non-null  int64
#  2   gill-attachment  54035 non-null  int64
#  3   gill-color       54035 non-null  int64
#  4   stem-height      54035 non-null  float64
#  5   stem-width       54035 non-null  int64
#  6   stem-color       54035 non-null  int64
#  7   season           54035 non-null  float64
#  8   class            54035 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 3.7 MB

# %% [markdown]
# **Dataset Overview (from `info()`)**
#
# - **Rows**: 54,035
# - **Columns**: 9
# - **Data Types**: 7 integer (`int64`), 2 float (`float64`)
# - **Missing Values**: None
#
# The dataset looks clean, complete, and ready for binary classification tasks.

# %% [markdown]
# ### 2. Data cleaning:

# %% [markdown]
# To ensure data quality and avoid bias in the model, we need to remove duplicate rows from the dataset.

# %%
mushroom_df = mushroom_df.drop_duplicates()
mushroom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53732 entries, 0 to 54034
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cap-diameter     53732 non-null  int64
#  1   cap-shape        53732 non-null  int64
#  2   gill-attachment  53732 non-null  int64
#  3   gill-color       53732 non-null  int64
#  4   stem-height      53732 non-null  float64
#  5   stem-width       53732 non-null  int64
#  6   stem-color       53732 non-null  int64
#  7   season           53732 non-null  float64
#  8   class            53732 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 4.1 MB

# %% [markdown]
# We will display the descriptive statistics of the dataset.

# %%
mushroom_df.describe()
# Out:
#        cap-diameter     cap-shape  gill-attachment    gill-color  \
# count  53732.000000  53732.000000     53732.000000  53732.000000
# mean     568.629178      4.005900         2.142857      7.344599
# std      360.384461      2.165188         2.232546      3.190447
# min        0.000000      0.000000         0.000000      0.000000
# 25%      290.000000      2.000000         0.000000      5.000000
# 50%      528.000000      5.000000         1.000000      8.000000
# 75%      782.000000      6.000000         4.000000     10.000000
# max     1891.000000      6.000000         6.000000     11.000000
#
#         stem-height    stem-width    stem-color        season         class
# count  53732.000000  53732.000000  53732.000000  53732.000000  53732.000000
# mean       0.752102   1057.000633      8.454013      0.952322      0.546639
# std        0.645987    780.263033      3.235507      0.303795      0.497825
# min        0.000426      0.000000      0.000000      0.027372      0.000000
# ...

# %%
plt.figure(figsize=(15, 12))
for i, col in enumerate(mushroom_df.columns, 1):
    plt.subplot(3, 3, i)  
    sns.histplot(mushroom_df[col], kde=True, color="skyblue", bins=20)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Observations from the Distribution Plots
#
# 1. **Cap-Diameter**:
#    - The data is **right-skewed** with most values concentrated between **250 to 750**.
#    - A few larger cap diameters act as outliers.
#
# 2. **Cap-Shape**:
#    - The values are discrete with **categories** ranging from 0 to 6.
#    - Two categories (0 and 6) dominate the distribution.
#
# 3. **Gill-Attachment**:
#    - The distribution is fairly balanced across categories, but some (e.g., **category 0**) appear more frequently.
#
# 4. **Gill-Color**:
#    - The data has **multiple peaks**, suggesting **common color categories** (e.g., 0, 10).
#    - Some categories occur far less frequently.
#
# 5. **Stem-Height**:
#    - The data is **right-skewed** with most heights concentrated between **0.5 to 2.5**.
#    - There are very few mushrooms with a stem height greater than 3.
#
# 6. **Stem-Width**:
#    - The distribution shows a **gradual decline**, with most widths under **1500 units**.
#    - A long tail exists, indicating some wider stems.
#
# 7. **Stem-Color**:
#    - The data has clear **peaks**, with a few dominant categories (e.g., 0 and 10).
#    - Less frequent colors are scattered throughout.
#
# 8. **Season**:
#    - The values are **grouped around 0.5 and 1.0**, indicating seasonality may only have **2-3 key periods**.
#
# 9. **Class (Target Variable)**:
#    - The dataset is **imbalanced** with significantly more values for class `0` (edible) than class `1` (poisonous).
#    - This imbalance may impact model performance and will need attention during model training.

# %% [markdown]
# To identify relationships between numerical features, we will calculate the correlation matrix and visualize it using a heatmap. This will help us understand which features are strongly or weakly correlated and may assist in feature selection or engineering.

# %%
correlation_matrix = mushroom_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Features")
plt.show()

# %% [markdown]
# From the heatmap, we observe that **`stem-width`** and **`cap-diameter`** have a very high positive correlation (**0.83**).
#
# 1. **Multicollinearity**:
#    High correlation between features can lead to multicollinearity, which causes redundancy in the data. Including both features in the model does not provide additional value and can confuse certain algorithms, particularly linear models.
#
# 2. **Model Efficiency**:
#    Removing one of the highly correlated features can simplify the model, reduce computation time, and improve interpretability without losing much information.

# %% [markdown]
# `stem-width` removing

# %%
mushroom_df = mushroom_df.drop(columns='stem-width')

# %% [markdown]
# At this stage, the data is cleaned, preprocessed, and free of redundancy. The dataset is now ready for model training and evaluation.

# %% [markdown]
# ### 3. Data splitting

# %% [markdown]
# We will divide the dataset as follows:
# - **60%** for training data
# - **20%** for testing data
# - **20%** for validation data
# This split ensures a balanced distribution for model training, testing, and evaluation.

# %%
y = mushroom_df['class']
x = mushroom_df.drop('class', axis=1)

Xtrain, Xtest, ytrain, ytest = train_test_split(x, y, test_size=0.4, random_state=random_seed)

display(Xtrain.shape)
display(ytrain.shape)
display(Xtest.shape)
display(ytest.shape)
# Out:
# (32239, 7)
# (32239,)
# (21493, 7)
# (21493,)

# %%
Xval, Xtest, yval, ytest = train_test_split(Xtest, ytest, test_size=0.5, random_state=random_seed)

display(Xval.shape)
display(yval.shape)
display(Xtest.shape)
display(ytest.shape)
# Out:
# (10746, 7)
# (10746,)
# (10747, 7)
# (10747,)

# %% [markdown]
# We will create a graph to illustrate how the data is divided into training, validation, and test sets. This will help ensure the splits are clear and properly balanced.

# %%
def plot_data_distribution(Xtrain, Xval, Xtest):
    sizes = [len(Xtrain), len(Xval), len(Xtest)]
    labels = ['Training Set', 'Validation Set', 'Test Set']
    percentages = [size / sum(sizes) * 100 for size in sizes]

    plt.figure(figsize=(8, 6))
    plt.bar(labels, percentages, color=['skyblue', 'lightgreen', 'lightcoral'], edgecolor='black')
    plt.title("Data Distribution Across Training, Validation, and Test Sets")
    plt.ylabel("Percentage")
    plt.ylim(0, 100)
    
    for i, v in enumerate(percentages):
        plt.text(i, v + 1, f"{v:.2f}%", ha='center', fontsize=10)

    plt.grid(linewidth = .4, alpha = .4)
    plt.show()

# %%
plot_data_distribution(Xtrain, Xval, Xtest)

# %% [markdown]
# #### Conclusion of Data Preparation
# The data has been cleaned, missing values handled, categorical features encoded, and the dataset split into training, testing, and validation sets. We are now ready to move on to model training.

# %% [markdown]
# ## 3. Model

# %% [markdown]
# We need to prepare data subsets for KNN. For this, we perform min-max normalization.

# %%
scaler = MinMaxScaler()
scaler.fit(Xtrain)

Xtrain_scaled = scaler.transform(Xtrain)
Xval_scaled = scaler.transform(Xval)
Xtest_scaled = scaler.transform(Xtest)

# %% [markdown]
# We iterate over all hyperparameter combinations for KNN, train the model, and store accuracy for training and validation sets; then, we select the parameters with the highest validation accuracy.

# %%
param_grid = {
    'n_neighbors': range(5, 20),  
    'weights': ['uniform', 'distance'],
    'metric': ['minkowski', 'manhattan']  
}

params_comb = ParameterGrid(param_grid)

# %%
train_accuracy = []
val_accuracy = []
train_f1 = []
val_f1 = []

for params in params_comb:
    knn = KNeighborsClassifier(**params)  
    knn.fit(Xtrain_scaled, ytrain)  

    ytrain_pred = knn.predict(Xtrain_scaled)
    yval_pred = knn.predict(Xval_scaled)

    train_accuracy.append(accuracy_score(ytrain, ytrain_pred))
    val_accuracy.append(accuracy_score(yval, yval_pred))
    train_f1.append(f1_score(ytrain, ytrain_pred))
    val_f1.append(f1_score(yval, yval_pred))

results = pd.DataFrame(params_comb)
results['train_accuracy'] = train_accuracy
results['val_accuracy'] = val_accuracy
results['train_f1'] = train_f1
results['val_f1'] = val_f1

plt.style.use('default')

# %%
def plot_knn_results(results):
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))
    
    ax[0].plot(range(len(results)), results['train_accuracy'], 'o-', label='Train Accuracy', color='blue')
    ax[0].plot(range(len(results)), results['val_accuracy'], 'o-', label='Validation Accuracy', color='orange')
    ax[0].set_title('Accuracy for k-NN Hyperparameters')
    ax[0].set_xlabel('Parameter Combination Index')
    ax[0].set_ylabel('Accuracy')
    ax[0].legend()
    ax[0].grid()  

    ax[1].plot(range(len(results)), results['train_f1'], 'o-', label='Train F1-Score', color='green')
    ax[1].plot(range(len(results)), results['val_f1'], 'o-', label='Validation F1-Score', color='purple')
    ax[1].set_title('F1-Score for k-NN Hyperparameters')
    ax[1].set_xlabel('Parameter Combination Index')
    ax[1].set_ylabel('F1-Score')
    ax[1].legend()
    ax[1].grid()

    plt.tight_layout()
    plt.show()

# %%
plot_knn_results(results)

# %% [markdown]
# # **Accuracy (left):**
#
# **Train Accuracy (blue)**: Close to 1.0 for most hyperparameters, indicating overfitting as the model memorizes training data.
#
# **Validation Accuracy (orange):** Much lower than training accuracy, showing the model struggles to generalize. Variations suggest sensitivity to hyperparameters like n_neighbors.
#
#
# # **F1-Score (right):**
#
# **Train F1-Score (green):**
# Also near 1.0, reinforcing overfitting.
#
# **Validation F1-Score (purple):** Lower and fluctuates similarly to validation accuracy, reflecting how the model's balance of precision and recall varies.
#
#
# # **Insights:**
# Overfitting is evident, with high training metrics but lower validation performance.
# Hyperparameters like n_neighbors and metric strongly influence validation results.
# Improving generalization may require regularization or fine-tuning hyperparameters to reduce the performance gap.

# %%
best_index = results['val_accuracy'].idxmax()  
best_params = params_comb[best_index]

knn = KNeighborsClassifier(**best_params)
knn.fit(Xtrain_scaled, ytrain)

train_accuracy = metrics.accuracy_score(ytrain, knn.predict(Xtrain_scaled))
val_accuracy = metrics.accuracy_score(yval, knn.predict(Xval_scaled))
test_accuracy = metrics.accuracy_score(ytest, knn.predict(Xtest_scaled))

print('accuracy score (train): {0:.6f}'.format(train_accuracy))
print('accuracy score (validation): {0:.6f}'.format(val_accuracy))
print('accuracy score (test): {0:.6f}'.format(test_accuracy))
# Out:
# accuracy score (train): 0.999969
# accuracy score (validation): 0.970221
# accuracy score (test): 0.972178

# %%
ConfusionMatrixDisplay.from_estimator(knn, Xtest_scaled, ytest)
plt.show()

# %% [markdown]
# The model performs well in predicting both classes. It correctly classified majority of instances of class 0 and of class 1. There is a relatively small number of false positives and false negatives. The model has great accuracy

# %%
y_test_prob = knn.predict_proba(Xtest_scaled)[:, 1]

fpr, tpr, roc_thresholds = roc_curve(ytest, y_test_prob)
roc_auc = auc(fpr, tpr)

precision, recall, pr_thresholds = precision_recall_curve(ytest, y_test_prob)
average_precision = average_precision_score(ytest, y_test_prob)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

axes[0].plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
axes[0].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
axes[0].set_xlabel('False Positive Rate')
axes[0].set_ylabel('True Positive Rate')
axes[0].set_title('Receiver Operating Characteristic (ROC) Curve')
axes[0].legend(loc='lower right')
axes[0].grid()

axes[1].plot(recall, precision, color='blue', lw=2, label=f'PR Curve (AP = {average_precision:.2f})')
axes[1].set_xlabel('Recall')
axes[1].set_ylabel('Precision')
axes[1].set_title('Precision-Recall Curve')
axes[1].legend(loc='lower left')
axes[1].grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# These plots visualize the performance of the k-NN model using **ROC** and **Precision-Recall (PR) curves**:
#
# **ROC Curve (left):**
#
# The curve shows the trade-off between True Positive Rate (sensitivity) and False Positive Rate for various thresholds.
# The Area Under the Curve (AUC) is 0.99, indicating excellent model performance, as the curve is close to the top-left corner.
#
# **PR Curve (right):**
#
# This curve focuses on the relationship between precision (positive predictive value) and recall (sensitivity).
# The Average Precision (AP) score is 0.99, further confirming that the model performs well in distinguishing between classes, even with imbalanced data.
#
# **Insights:**
# Both metrics demonstrate near-perfect model performance, with high precision, recall, and AUC scores.
# The model is well-calibrated, minimizing false positives and negatives effectively.

# %% [markdown]
# # THE END
